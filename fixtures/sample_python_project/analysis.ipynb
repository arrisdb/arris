# %% [markdown]
# # Sales Analysis
#
# Sample notebook for testing **Arris** notebook support. Everything here uses
# only the Python standard library, so you can pick *any* Python 3 interpreter
# from the dropdown and hit **Run all**.
#
# It exercises:
#
# - Markdown cells (this one) with `inline code`, **bold**, *italic* and [links](https://docs.jupyter.org)
# - `stdout` streaming output
# - `execute_result` values
# - a deliberate error + traceback
# - a raw cell

# %%
import statistics

sales = [120, 95, 143, 88, 167, 210, 130]
print(f"Days recorded: {len(sales)}")
print(f"Total units: {sum(sales)}")

# %% [markdown]
# ## Summary statistics
#
# Mean, median and population standard deviation of daily sales.

# %%
{
    "mean": round(statistics.mean(sales), 2),
    "median": statistics.median(sales),
    "stdev": round(statistics.pstdev(sales), 2),
}

# %% [markdown]
# ## Best day

# %%
peak = max(range(len(sales)), key=lambda i: sales[i])
f"Best day: #{peak + 1} with {sales[peak]} units"

# %% [markdown]
# ## Error handling demo
#
# The cell below intentionally raises so you can see how Arris renders a
# kernel traceback.

# %%
sales[00]

# %%
import time
time.sleep(1)
print(2)

# %%
print(123)
# Out:
# 123

# %%
1
